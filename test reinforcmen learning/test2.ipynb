# %%
# !pip install tensorflow==2.3.0
# !pip install keras
# !pip install keras-rl2
# !pip install baselines
# Out:
# Requirement already satisfied: tensorflow==2.3.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (2.3.0)
# Requirement already satisfied: wheel>=0.26 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (0.36.2)
# Requirement already satisfied: absl-py>=0.7.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (0.12.0)
# Requirement already satisfied: wrapt>=1.11.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (1.12.1)
# Requirement already satisfied: six>=1.12.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (1.32.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (1.1.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (1.1.2)
# Requirement already satisfied: protobuf>=3.9.2 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (3.12.4)
# Requirement already satisfied: google-pasta>=0.1.8 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (0.2.0)
# Requirement already satisfied: gast==0.3.3 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (0.3.3)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (1.18.5)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (2.3.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (2.10.0)
# Requirement already satisfied: astunparse==1.6.3 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (1.6.3)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (2.4.1)
# Requirement already satisfied: scipy==1.4.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow==2.3.0) (1.4.1)
# Requirement already satisfied: setuptools in d:\instalado\anaconda3\envs\tf\lib\site-packages (from protobuf>=3.9.2->tensorflow==2.3.0) (49.6.0.post20200814)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.6.0)
# Requirement already satisfied: werkzeug>=0.11.15 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.16.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.24.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.20.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.25.10)
# Requirement already satisfied: idna<3,>=2.5 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.10)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in d:\instalado\anaconda3\envs\tf\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in d:\instalado\anaconda3\envs\tf\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.8)
# Requirement already satisfied: keras in d:\instalado\anaconda3\envs\tf\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.9.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from keras) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from keras) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from keras) (1.15.0)
# Requirement already satisfied: pyyaml in d:\instalado\anaconda3\envs\tf\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: h5py in d:\instalado\anaconda3\envs\tf\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: keras_applications>=1.0.6 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from keras) (1.0.8)
# Requirement already satisfied: keras_preprocessing>=1.0.5 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from keras) (1.1.2)
# Requirement already satisfied: keras-rl2 in d:\instalado\anaconda3\envs\tf\lib\site-packages (1.0.4)
# Requirement already satisfied: tensorflow>=2.1.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from keras-rl2) (2.3.0)
# Requirement already satisfied: gast==0.3.3 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (0.3.3)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.12.1)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (2.10.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (2.4.1)
# Requirement already satisfied: grpcio>=1.8.6 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.32.0)
# Requirement already satisfied: protobuf>=3.9.2 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (3.12.4)
# Requirement already satisfied: wheel>=0.26 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (0.36.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (3.3.0)
# Requirement already satisfied: absl-py>=0.7.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (0.12.0)
# Requirement already satisfied: scipy==1.4.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.4.1)
# Requirement already satisfied: six>=1.12.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.1.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.18.5)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (2.3.0)
# Requirement already satisfied: google-pasta>=0.1.8 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (0.2.0)
# Requirement already satisfied: astunparse==1.6.3 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.6.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.6.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.20.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (3.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (0.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (2.24.0)
# Requirement already satisfied: werkzeug>=0.11.15 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (0.16.1)
# Requirement already satisfied: setuptools>=41.0.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (49.6.0.post20200814)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in d:\instalado\anaconda3\envs\tf\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (0.2.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in d:\instalado\anaconda3\envs\tf\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.3.0)
# Requirement already satisfied: idna<3,>=2.5 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (2020.6.20)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (3.1.0)
# Collecting baselines
#   Using cached baselines-0.1.5.tar.gz (123 kB)
# Requirement already satisfied: gym[atari,classic_control,mujoco,robotics] in d:\instalado\anaconda3\envs\tf\lib\site-packages (from baselines) (0.18.0)
# Requirement already satisfied: scipy in d:\instalado\anaconda3\envs\tf\lib\site-packages (from baselines) (1.4.1)
# Collecting tqdm
#   Downloading tqdm-4.60.0-py2.py3-none-any.whl (75 kB)
# Collecting joblib
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting zmq
#   Using cached zmq-0.0.0.tar.gz (966 bytes)
# Collecting dill
#   Using cached dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting progressbar2
#   Using cached progressbar2-3.53.1-py2.py3-none-any.whl (25 kB)
# Collecting mpi4py
#   Downloading mpi4py-3.0.3-cp37-cp37m-win_amd64.whl (477 kB)
# Requirement already satisfied: cloudpickle in d:\instalado\anaconda3\envs\tf\lib\site-packages (from baselines) (1.5.0)
# Requirement already satisfied: tensorflow>=1.4.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from baselines) (2.3.0)
# Requirement already satisfied: click in d:\instalado\anaconda3\envs\tf\lib\site-packages (from baselines) (7.1.2)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from gym[atari,classic_control,mujoco,robotics]->baselines) (1.5.0)
# Requirement already satisfied: Pillow<=7.2.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from gym[atari,classic_control,mujoco,robotics]->baselines) (7.2.0)
# Requirement already satisfied: numpy>=1.10.4 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from gym[atari,classic_control,mujoco,robotics]->baselines) (1.18.5)
# Collecting opencv-python>=3.; extra == "atari"
#   Downloading opencv_python-4.5.2.52-cp37-cp37m-win_amd64.whl (34.7 MB)
# Collecting atari-py~=0.2.0; extra == "atari"
#   Downloading atari_py-0.2.6-cp37-cp37m-win_amd64.whl (1.8 MB)
# Collecting imageio; extra == "mujoco"
#   Using cached imageio-2.9.0-py3-none-any.whl (3.3 MB)
# Collecting mujoco-py<2.0,>=1.50; extra == "mujoco"
#   Using cached mujoco-py-1.50.1.68.tar.gz (120 kB)
# Requirement already satisfied: pyzmq in d:\instalado\anaconda3\envs\tf\lib\site-packages (from zmq->baselines) (19.0.1)
# Collecting python-utils>=2.3.0
#   Downloading python_utils-2.5.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six in d:\instalado\anaconda3\envs\tf\lib\site-packages (from progressbar2->baselines) (1.15.0)
# Requirement already satisfied: protobuf>=3.9.2 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (3.12.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.1.0)
# Requirement already satisfied: gast==0.3.3 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (0.3.3)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (2.10.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (2.3.0)
# Requirement already satisfied: google-pasta>=0.1.8 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (0.2.0)
# Requirement already satisfied: grpcio>=1.8.6 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.32.0)
# Requirement already satisfied: absl-py>=0.7.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (0.12.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.1.2)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (2.4.1)
# Requirement already satisfied: wrapt>=1.11.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.12.1)
# Requirement already satisfied: wheel>=0.26 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (0.36.2)
# Requirement already satisfied: astunparse==1.6.3 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.6.3)
# Requirement already satisfied: future in d:\instalado\anaconda3\envs\tf\lib\site-packages (from pyglet<=1.5.0,>=1.4.0->gym[atari,classic_control,mujoco,robotics]->baselines) (0.18.2)
# Collecting glfw>=1.4.0
#   Downloading glfw-2.1.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-win_amd64.whl (491 kB)
# Collecting Cython>=0.27.2
#   Downloading Cython-0.29.23-cp37-cp37m-win_amd64.whl (1.6 MB)
# Requirement already satisfied: cffi>=1.10 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from mujoco-py<2.0,>=1.50; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (1.14.0)
# Collecting lockfile>=0.12.2
#   Using cached lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: setuptools in d:\instalado\anaconda3\envs\tf\lib\site-packages (from protobuf>=3.9.2->tensorflow>=1.4.0->baselines) (49.6.0.post20200814)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.6.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (2.24.0)
# Requirement already satisfied: werkzeug>=0.11.15 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (0.16.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (3.2.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.20.1)
# Requirement already satisfied: pycparser in d:\instalado\anaconda3\envs\tf\lib\site-packages (from cffi>=1.10->mujoco-py<2.0,>=1.50; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (2.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (2020.6.20)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in d:\instalado\anaconda3\envs\tf\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.7.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in d:\instalado\anaconda3\envs\tf\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (0.2.7)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\instalado\anaconda3\envs\tf\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (0.4.8)
# Building wheels for collected packages: baselines, zmq, mujoco-py
#   Building wheel for baselines (setup.py): started
#   Building wheel for baselines (setup.py): finished with status 'done'
#   Created wheel for baselines: filename=baselines-0.1.5-py3-none-any.whl size=163901 sha256=b0804bfd47a834be2a0938327795350779454dcb632a1b75af6a2f30763df3c6
#   Stored in directory: c:\users\mpier\appdata\local\pip\cache\wheels\64\27\40\3b266f230c825e6b219bfdd5447566d4d109b66fc4e0c074ed
#   Building wheel for zmq (setup.py): started
#   Building wheel for zmq (setup.py): finished with status 'done'
#   Created wheel for zmq: filename=zmq-0.0.0-py3-none-any.whl size=1276 sha256=ec601713ed05a1320e232748b60b9c9b7dcdbca64eae4490078f7dbbe96492ca
#   Stored in directory: c:\users\mpier\appdata\local\pip\cache\wheels\3d\19\38\5312d02df169de6d79ffa36d2096b3affd5cf8e44682acd749
#   Building wheel for mujoco-py (setup.py): started
#   Building wheel for mujoco-py (setup.py): finished with status 'error'
#   Running setup.py clean for mujoco-py
# Successfully built baselines zmq
# Failed to build mujoco-py
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\Instalado\anaconda3\envs\tf\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mpier\\AppData\\Local\\Temp\\pip-install-x5l0h442\\mujoco-py\\setup.py'"'"'; __file__='"'"'C:\\Users\\mpier\\AppData\\Local\\Temp\\pip-install-x5l0h442\\mujoco-py\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\mpier\AppData\Local\Temp\pip-wheel-nb2il7g2'
#        cwd: C:\Users\mpier\AppData\Local\Temp\pip-install-x5l0h442\mujoco-py\
#   Complete output (27 lines):
#   running bdist_wheel
#   running build
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\mpier\AppData\Local\Temp\pip-install-x5l0h442\mujoco-py\setup.py", line 44, in <module>
#       tests_require=read_requirements_file('requirements.dev.txt'),
#     File "D:\Instalado\anaconda3\envs\tf\lib\site-packages\setuptools\__init__.py", line 163, in setup
#       return distutils.core.setup(**attrs)
#     File "D:\Instalado\anaconda3\envs\tf\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "D:\Instalado\anaconda3\envs\tf\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "D:\Instalado\anaconda3\envs\tf\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "D:\Instalado\anaconda3\envs\tf\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "D:\Instalado\anaconda3\envs\tf\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "D:\Instalado\anaconda3\envs\tf\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\mpier\AppData\Local\Temp\pip-install-x5l0h442\mujoco-py\setup.py", line 28, in run
#       import mujoco_py  # noqa: force build
#     File "C:\Users\mpier\AppData\Local\Temp\pip-install-x5l0h442\mujoco-py\mujoco_py\__init__.py", line 3, in <module>
#       from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#     File "C:\Users\mpier\AppData\Local\Temp\pip-install-x5l0h442\mujoco-py\mujoco_py\builder.py", line 17, in <module>
#       from Cython.Build import cythonize
#   ModuleNotFoundError: No module named 'Cython'
#   ----------------------------------------
#   ERROR: Failed building wheel for mujoco-py
# DEPRECATION: Could not build wheels for mujoco-py which do not use PEP 517. pip will fall back to legacy 'setup.py install' for these. pip 21.0 will remove support for this functionality. A possible replacement is to fix the wheel build issue reported above. You can find discussion regarding this at https://github.com/pypa/pip/issues/8368.
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Instalado\anaconda3\envs\tf\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mpier\\AppData\\Local\\Temp\\pip-install-x5l0h442\\mujoco-py\\setup.py'"'"'; __file__='"'"'C:\\Users\\mpier\\AppData\\Local\\Temp\\pip-install-x5l0h442\\mujoco-py\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\mpier\AppData\Local\Temp\pip-record-vgm29b9a\install-record.txt' --single-version-externally-managed --compile --install-headers 'D:\Instalado\anaconda3\envs\tf\Include\mujoco-py'
#          cwd: C:\Users\mpier\AppData\Local\Temp\pip-install-x5l0h442\mujoco-py\
#     Complete output (56 lines):
#     running install
#     running build
#
#     You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\mpier\.mujoco\mjpro150
#
#     This package only provides python bindings, the library must be installed separately.
#
#     Please follow the instructions on the README to install MuJoCo
#
#         https://github.com/openai/mujoco-py#install-mujoco
#
#     Which can be downloaded from the website
#
#         https://www.roboti.us/index.html
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\mpier\AppData\Local\Temp\pip-install-x5l0h442\mujoco-py\setup.py", line 44, in <module>
#         tests_require=read_requirements_file('requirements.dev.txt'),
#       File "D:\Instalado\anaconda3\envs\tf\lib\site-packages\setuptools\__init__.py", line 163, in setup
#         return distutils.core.setup(**attrs)
#       File "D:\Instalado\anaconda3\envs\tf\lib\distutils\core.py", line 148, in setup
#         dist.run_commands()
#       File "D:\Instalado\anaconda3\envs\tf\lib\distutils\dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "D:\Instalado\anaconda3\envs\tf\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "D:\Instalado\anaconda3\envs\tf\lib\site-packages\setuptools\command\install.py", line 61, in run
#         return orig.install.run(self)
#       File "D:\Instalado\anaconda3\envs\tf\lib\distutils\command\install.py", line 545, in run
#         self.run_command('build')
#       File "D:\Instalado\anaconda3\envs\tf\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "D:\Instalado\anaconda3\envs\tf\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\mpier\AppData\Local\Temp\pip-install-x5l0h442\mujoco-py\setup.py", line 28, in run
#         import mujoco_py  # noqa: force build
#       File "C:\Users\mpier\AppData\Local\Temp\pip-install-x5l0h442\mujoco-py\mujoco_py\__init__.py", line 3, in <module>
#         from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#       File "C:\Users\mpier\AppData\Local\Temp\pip-install-x5l0h442\mujoco-py\mujoco_py\builder.py", line 502, in <module>
#         mjpro_path, key_path = discover_mujoco()
#       File "C:\Users\mpier\AppData\Local\Temp\pip-install-x5l0h442\mujoco-py\mujoco_py\utils.py", line 93, in discover_mujoco
#         raise Exception(message)
#     Exception:
#     You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\mpier\.mujoco\mjpro150
#
#     This package only provides python bindings, the library must be installed separately.
#
#     Please follow the instructions on the README to install MuJoCo
#
#         https://github.com/openai/mujoco-py#install-mujoco
#
#     Which can be downloaded from the website
#
#         https://www.roboti.us/index.html
#
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'D:\Instalado\anaconda3\envs\tf\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mpier\\AppData\\Local\\Temp\\pip-install-x5l0h442\\mujoco-py\\setup.py'"'"'; __file__='"'"'C:\\Users\\mpier\\AppData\\Local\\Temp\\pip-install-x5l0h442\\mujoco-py\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\mpier\AppData\Local\Temp\pip-record-vgm29b9a\install-record.txt' --single-version-externally-managed --compile --install-headers 'D:\Instalado\anaconda3\envs\tf\Include\mujoco-py' Check the logs for full command output.
# Installing collected packages: tqdm, joblib, zmq, dill, python-utils, progressbar2, mpi4py, baselines, opencv-python, atari-py, imageio, glfw, Cython, lockfile, mujoco-py
#     Running setup.py install for mujoco-py: started
#     Running setup.py install for mujoco-py: finished with status 'error'

# %%
"""
Title: Deep Q-Learning for Atari Breakout
Author: [Jacob Chapman](https://twitter.com/jacoblchapman) and [Mathias Lechner](https://twitter.com/MLech20)
Date created: 2020/05/23
Last modified: 2020/06/17
Description: Play Atari Breakout with a Deep Q-Network.
"""
"""
## Introduction

This script shows an implementation of Deep Q-Learning on the
`BreakoutNoFrameskip-v4` environment.

### Deep Q-Learning

As an agent takes actions and moves through an environment, it learns to map
the observed state of the environment to an action. An agent will choose an action
in a given state based on a "Q-value", which is a weighted reward based on the
expected highest long-term reward. A Q-Learning Agent learns to perform its
task such that the recommended action maximizes the potential future rewards.
This method is considered an "Off-Policy" method,
meaning its Q values are updated assuming that the best action was chosen, even
if the best action was not chosen.

### Atari Breakout

In this environment, a board moves along the bottom of the screen returning a ball that
will destroy blocks at the top of the screen.
The aim of the game is to remove all blocks and breakout of the
level. The agent must learn to control the board by moving left and right, returning the
ball and removing all the blocks without the ball passing the board.

### Note

The Deepmind paper trained for "a total of 50 million frames (that is, around 38 days of
game experience in total)". However this script will give good results at around 10
million frames which are processed in less than 24 hours on a modern machine.

### References

- [Q-Learning](https://link.springer.com/content/pdf/10.1007/BF00992698.pdf)
- [Deep Q-Learning](https://deepmind.com/research/publications/human-level-control-through-deep-reinforcement-learning)
"""
"""
## Setup
"""

from baselines.common.atari_wrappers import make_atari, wrap_deepmind
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Configuration paramaters for the whole setup
seed = 42
gamma = 0.99  # Discount factor for past rewards
epsilon = 1.0  # Epsilon greedy parameter
epsilon_min = 0.1  # Minimum epsilon greedy parameter
epsilon_max = 1.0  # Maximum epsilon greedy parameter
epsilon_interval = (
    epsilon_max - epsilon_min
)  # Rate at which to reduce chance of random action being taken
batch_size = 32  # Size of batch taken from replay buffer
max_steps_per_episode = 10000

# %%
# Use the Baseline Atari environment because of Deepmind helper functions
env = make_atari("BreakoutNoFrameskip-v4")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-569874650224> in <module>
#       1 # Use the Baseline Atari environment because of Deepmind helper functions
# ----> 2 env = make_atari("BreakoutNoFrameskip-v4")
#
# D:\Instalado\anaconda3\envs\tf\lib\site-packages\baselines\common\atari_wrappers.py in make_atari(env_id)
#     215
#     216 def make_atari(env_id):
# --> 217     env = gym.make(env_id)
#     218     assert 'NoFrameskip' in env.spec.id
#     219     env = NoopResetEnv(env, noop_max=30)
#
# D:\Instalado\anaconda3\envs\tf\lib\site-packages\gym\envs\registration.py in make(id, **kwargs)
#     143
#     144 def make(id, **kwargs):
# --> 145     return registry.make(id, **kwargs)
#     146
#     147 def spec(id):
#
# D:\Instalado\anaconda3\envs\tf\lib\site-packages\gym\envs\registration.py in make(self, path, **kwargs)
#      88             logger.info('Making new env: %s', path)
#      89         spec = self.spec(path)
# ---> 90         env = spec.make(**kwargs)
#      91         # We used to have people override _reset/_step rather than
#      92         # reset/step. Set _gym_disable_underscore_compat = True on
#
# D:\Instalado\anaconda3\envs\tf\lib\site-packages\gym\envs\registration.py in make(self, **kwargs)
#      57             env = self.entry_point(**_kwargs)
#      58         else:
# ---> 59             cls = load(self.entry_point)
#      60             env = cls(**_kwargs)
#      61
#
# D:\Instalado\anaconda3\envs\tf\lib\site-packages\gym\envs\registration.py in load(name)
#      16 def load(name):
#      17     mod_name, attr_name = name.split(":")
# ---> 18     mod = importlib.import_module(mod_name)
#      19     fn = getattr(mod, attr_name)
#      20     return fn
#
# D:\Instalado\anaconda3\envs\tf\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# D:\Instalado\anaconda3\envs\tf\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# D:\Instalado\anaconda3\envs\tf\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# D:\Instalado\anaconda3\envs\tf\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# D:\Instalado\anaconda3\envs\tf\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# D:\Instalado\anaconda3\envs\tf\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# D:\Instalado\anaconda3\envs\tf\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# D:\Instalado\anaconda3\envs\tf\lib\site-packages\gym\envs\atari\__init__.py in <module>
# ----> 1 from gym.envs.atari.atari_env import AtariEnv
#
# D:\Instalado\anaconda3\envs\tf\lib\site-packages\gym\envs\atari\atari_env.py in <module>
#       7
#       8 try:
# ----> 9     import atari_py
#      10 except ImportError as e:
#      11     raise error.DependencyNotInstalled(
#
# D:\Instalado\anaconda3\envs\tf\lib\site-packages\atari_py\__init__.py in <module>
# ----> 1 from .ale_python_interface import *
#       2 import os
#       3
#       4 def _game_dir():
#       5     return os.path.join(os.path.abspath(os.path.dirname(__file__)), "atari_roms")
#
# D:\Instalado\anaconda3\envs\tf\lib\site-packages\atari_py\ale_python_interface.py in <module>
#      16 else:
#      17     ale_lib = cdll.LoadLibrary(os.path.join(os.path.dirname(__file__),
# ---> 18                                             'ale_interface/ale_c.dll'))
#      19
#      20 ale_lib.ALE_new.argtypes = None
#
# D:\Instalado\anaconda3\envs\tf\lib\ctypes\__init__.py in LoadLibrary(self, name)
#     440
#     441     def LoadLibrary(self, name):
# --> 442         return self._dlltype(name)
#     443
#     444 cdll = LibraryLoader(CDLL)
#
# D:\Instalado\anaconda3\envs\tf\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     362
#     363         if handle is None:
# --> 364             self._handle = _dlopen(self._name, mode)
#     365         else:
#     366             self._handle = handle
#
# OSError: [WinError 126] The specified module could not be found

# %%
# Warp the frames, grey scale, stake four frame and scale to smaller ratio
env = wrap_deepmind(env, frame_stack=True, scale=True)
env.seed(seed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f066d4690e7c> in <module>
#       1 # Warp the frames, grey scale, stake four frame and scale to smaller ratio
# ----> 2 env = wrap_deepmind(env, frame_stack=True, scale=True)
#       3 env.seed(seed)
#
# NameError: name 'env' is not defined

# %%
"""
## Implement the Deep Q-Network

This network learns an approximation of the Q-table, which is a mapping between
the states and actions that an agent will take. For every state we'll have four
actions, that can be taken. The environment provides the state, and the action
is chosen by selecting the larger of the four Q-values predicted in the output layer.

"""

num_actions = 4


def create_q_model():
    # Network defined by the Deepmind paper
    inputs = layers.Input(shape=(84, 84, 4,))

    # Convolutions on the frames on the screen
    layer1 = layers.Conv2D(32, 8, strides=4, activation="relu")(inputs)
    layer2 = layers.Conv2D(64, 4, strides=2, activation="relu")(layer1)
    layer3 = layers.Conv2D(64, 3, strides=1, activation="relu")(layer2)

    layer4 = layers.Flatten()(layer3)

    layer5 = layers.Dense(512, activation="relu")(layer4)
    action = layers.Dense(num_actions, activation="linear")(layer5)

    return keras.Model(inputs=inputs, outputs=action)


# The first model makes the predictions for Q-values which are used to
# make a action.
model = create_q_model()
# Build a target model for the prediction of future rewards.
# The weights of a target model get updated every 10000 steps thus when the
# loss between the Q-values is calculated the target Q-value is stable.
model_target = create_q_model()

# %%
"""
## Train
"""
# In the Deepmind paper they use RMSProp however then Adam optimizer
# improves training time
optimizer = keras.optimizers.Adam(learning_rate=0.00025, clipnorm=1.0)

# Experience replay buffers
action_history = []
state_history = []
state_next_history = []
rewards_history = []
done_history = []
episode_reward_history = []
running_reward = 0
episode_count = 0
frame_count = 0
# Number of frames to take random action and observe output
epsilon_random_frames = 50000
# Number of frames for exploration
epsilon_greedy_frames = 1000000.0
# Maximum replay length
# Note: The Deepmind paper suggests 1000000 however this causes memory issues
max_memory_length = 100000
# Train the model after 4 actions
update_after_actions = 4
# How often to update the target network
update_target_network = 10000
# Using huber loss for stability
loss_function = keras.losses.Huber()

while True:  # Run until solved
    state = np.array(env.reset())
    episode_reward = 0

    for timestep in range(1, max_steps_per_episode):
        # env.render(); Adding this line would show the attempts
        # of the agent in a pop up window.
        frame_count += 1

        # Use epsilon-greedy for exploration
        if frame_count < epsilon_random_frames or epsilon > np.random.rand(1)[0]:
            # Take random action
            action = np.random.choice(num_actions)
        else:
            # Predict action Q-values
            # From environment state
            state_tensor = tf.convert_to_tensor(state)
            state_tensor = tf.expand_dims(state_tensor, 0)
            action_probs = model(state_tensor, training=False)
            # Take best action
            action = tf.argmax(action_probs[0]).numpy()

        # Decay probability of taking random action
        epsilon -= epsilon_interval / epsilon_greedy_frames
        epsilon = max(epsilon, epsilon_min)

        # Apply the sampled action in our environment
        state_next, reward, done, _ = env.step(action)
        state_next = np.array(state_next)

        episode_reward += reward

        # Save actions and states in replay buffer
        action_history.append(action)
        state_history.append(state)
        state_next_history.append(state_next)
        done_history.append(done)
        rewards_history.append(reward)
        state = state_next

        # Update every fourth frame and once batch size is over 32
        if frame_count % update_after_actions == 0 and len(done_history) > batch_size:

            # Get indices of samples for replay buffers
            indices = np.random.choice(range(len(done_history)), size=batch_size)

            # Using list comprehension to sample from replay buffer
            state_sample = np.array([state_history[i] for i in indices])
            state_next_sample = np.array([state_next_history[i] for i in indices])
            rewards_sample = [rewards_history[i] for i in indices]
            action_sample = [action_history[i] for i in indices]
            done_sample = tf.convert_to_tensor(
                [float(done_history[i]) for i in indices]
            )

            # Build the updated Q-values for the sampled future states
            # Use the target model for stability
            future_rewards = model_target.predict(state_next_sample)
            # Q value = reward + discount factor * expected future reward
            updated_q_values = rewards_sample + gamma * tf.reduce_max(
                future_rewards, axis=1
            )

            # If final frame set the last value to -1
            updated_q_values = updated_q_values * (1 - done_sample) - done_sample

            # Create a mask so we only calculate loss on the updated Q-values
            masks = tf.one_hot(action_sample, num_actions)

            with tf.GradientTape() as tape:
                # Train the model on the states and updated Q-values
                q_values = model(state_sample)

                # Apply the masks to the Q-values to get the Q-value for action taken
                q_action = tf.reduce_sum(tf.multiply(q_values, masks), axis=1)
                # Calculate loss between new Q-value and old Q-value
                loss = loss_function(updated_q_values, q_action)

            # Backpropagation
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))

        if frame_count % update_target_network == 0:
            # update the the target network with new weights
            model_target.set_weights(model.get_weights())
            # Log details
            template = "running reward: {:.2f} at episode {}, frame count {}"
            print(template.format(running_reward, episode_count, frame_count))

        # Limit the state and reward history
        if len(rewards_history) > max_memory_length:
            del rewards_history[:1]
            del state_history[:1]
            del state_next_history[:1]
            del action_history[:1]
            del done_history[:1]

        if done:
            break

    # Update running reward to check condition for solving
    episode_reward_history.append(episode_reward)
    if len(episode_reward_history) > 100:
        del episode_reward_history[:1]
    running_reward = np.mean(episode_reward_history)

    episode_count += 1

    if running_reward > 40:  # Condition to consider the task solved
        print("Solved at episode {}!".format(episode_count))
        break

# %%
"""
## Visualizations
Before any training:
![Imgur](https://i.imgur.com/rRxXF4H.gif)

In early stages of training:
![Imgur](https://i.imgur.com/X8ghdpL.gif)

In later stages of training:
![Imgur](https://i.imgur.com/Z1K6qBQ.gif)
"""
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-54d43f462051> in <module>
#      46 """
#      47
# ---> 48 from baselines.common.atari_wrappers import make_atari, wrap_deepmind
#      49 import numpy as np
#      50 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'baselines'
